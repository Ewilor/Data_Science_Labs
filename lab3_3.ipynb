# %% [markdown]
# Task 3

# %%
import numpy as np
import pandas as pd

X_manual = np.linspace(0, 50, 100)

noise = np.random.normal(0, 5, 100)
y_manual = 2 * X_manual + 5 + noise

df_manual = pd.DataFrame({'X': X_manual, 'y': y_manual})

print("\nРучна генерація:")
print(df_manual.head())
# Out:
# Ручна генерація (перші рядки):
#           X          y
# 0  0.000000   3.506939
# 1  0.505051  13.223301
# 2  1.010101  10.131622
# 3  1.515152   4.938963
# 4  2.020202  10.595409
